# %%
import numpy as np
import pandas as pd
import os
from Bio import SeqIO
import Bio
import Bio.PDB
import Bio.SeqRecord
from biopandas.pdb import PandasPdb
import pickle
from tqdm import tqdm
import os
import networkx as nx
from rnaglib.utils.graph_io import graph_from_pdbid

# %%
data_path = "./data/raw/solo_representative_pdb_all__3_258/1A3M_1_A-B.pdb"

from proteingraph import read_pdb

p = read_pdb(data_path)

# structure = Bio.PDB.PDBParser().get_structure('blah', data_path)
# for atom in structure.get_atoms():
#     if atom.name == "C5":
#         print(atom.name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [2], line 5
#       1 data_path = "./data/raw/solo_representative_pdb_all__3_258/1A3M_1_A-B.pdb"
#       3 from proteingraph import read_pdb
# ----> 5 p = read_pdb(data_path)
#
# File ~/opt/miniconda3/envs/diffrnafold/lib/python3.8/site-packages/proteingraph/pin.py:94, in read_pdb(path)
#      82 chain_pos_aa = compute_chain_pos_aa_mapping(pdb_df)
#      84 edge_funcs = [
#      85     partial(add_hydrophobic_interactions, rgroup_df=rgroup_df),
#      86     partial(add_disulfide_interactions, rgroup_df=rgroup_df),
#    (...)
#      91     partial(add_cation_pi_interactions, rgroup_df=rgroup_df),
#      92 ]
# ---> 94 G = compute_interaction_graph(pdb_df, chain_pos_aa, edge_funcs=edge_funcs)
#      95 convert_all_sets_to_lists(G)
#      96 return G
#
# ...

# %%
atomic_df = PandasPdb().read_pdb(data_path).df["ATOM"]
atomic_df["node_id"] = (
    atomic_df["chain_id"]
    + atomic_df["residue_number"].map(str)
    + atomic_df["residue_name"]
)
atomic_df
# Out:
#     record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0          ATOM            1                 P                    G
# 1          ATOM            2               C5'                    G
# 2          ATOM            3               O5'                    G
# 3          ATOM            4               C4'                    G
# 4          ATOM            5               O4'                    G
# ..          ...          ...     ...       ...     ...          ...     ...
# 862        ATOM          863               H4'                    C
# 863        ATOM          864               H41                    C
# 864        ATOM          865               H5'                    C
# 865        ATOM          866               H42                    C
# 866        ATOM          867              H5''                    C
#
#     chain_id  residue_number insertion  ... y_coord  z_coord  occupancy  \
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(atomic_df, x='x_coord', y='y_coord', z='z_coord',
              color='element_symbol')
fig.update_traces(marker_size = 3)
fig.show()

# %%
from torch_geometric.nn.conv import x_conv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 from torch_geometric.nn.conv import x_conv
#
# ModuleNotFoundError: No module named 'torch_geometric'
